# %%
'''
OUTLINE
Delete digits after three spaces <- use str.partition
Index matching: icd9 code with umbrella term <- use groupby
Create dictionary for each of the umbrella groups for new cases
'''

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('./icd9_index_2cols.csv')
print(df.dtypes)
# Out:
# Patient ID     object
# icd9           object
# icd9_group    float64
# dtype: object

# %%
#Convert column row to string

df['icd9'] = df['icd9'].astype(str)
print(df['icd9'])
# Out:
# 0                              729.5|
# 1                              447.6|
# 2                              729.5|
# 3                              225.2|
# 4                  351.8|368.8|784.0|
# 5                             V76.12|
# 6                              626.2|
# 7                             V76.12|
# 8                       729.5|729.81|
# 9                       729.5|729.81|
# 10                   511.9|428.0|514|
# 11                            959.01|
# 12                            959.09|
# 13               518.0|512.89|793.19|
# 14                             805.4|
# 15          511.9|805.4|807.09|860.0|
# 16               518.0|512.89|793.19|
# 17                     733.13|789.30|
# 18                             714.0|
# 19                             599.0|
# 20                             625.6|
# 21                             518.0|
# 22       V45.81|414.01|V58.81|V58.82|
# 23                     414.01|V58.81|
# 24         511.9|518.0|414.01|V58.81|
# 25                       723.1|723.4|
# 26                             218.9|
# 27                             218.9|
# 28                             959.3|
# 29                             959.6|
#                      ...
# 77414                          786.2|
# 77415                         733.00|
# 77416                         789.39|
# 77417                          V42.0|
# 77418                         786.50|
# 77419                    780.4|781.2|
# 77420            722.52|805.4|202.80|
# 77421                    780.4|781.2|
# 77422                    780.4|781.2|
# 77423                   627.9|733.00|
# 77424                  722.51|757.39|
# 77425                         715.95|
# 77426                         715.95|
# 77427      721.3|721.3|722.52|722.52|
# 77428                          241.1|
# 77429             719.46|724.5|V45.4|
# 77430                         719.46|
# 77431                     786.07|490|
# 77432                         786.50|
# 77433                          790.6|
# 77434              577.8|785.6|789.2|
# 77435              577.8|785.6|789.2|
# 77436                  959.01|780.97|
# 77437                  719.45|722.52|
# 77438                          191.9|
# 77439                          151.9|
# 77440        511.9|V58.81|514|793.19|
# 77441                          V55.1|
# 77442                  V58.81|793.19|
# 77443                         V58.82|
# Name: icd9, Length: 77444, dtype: object

# %%
#Use the delimiter '.' to partition the string and only keep the elements before the delimiter

df['icd9'] = df['icd9'].str.partition('.')[0]
print(df['icd9'])
# Out:
# 0        729
# 1        447
# 2        729
# 3        225
# 4        351
# 5        V76
# 6        626
# 7        V76
# 8        729
# 9        729
# 10       511
# 11       959
# 12       959
# 13       518
# 14       805
# 15       511
# 16       518
# 17       733
# 18       714
# 19       599
# 20       625
# 21       518
# 22       V45
# 23       414
# 24       511
# 25       723
# 26       218
# 27       218
# 28       959
# 29       959
#         ...
# 77414    786
# 77415    733
# 77416    789
# 77417    V42
# 77418    786
# 77419    780
# 77420    722
# 77421    780
# 77422    780
# 77423    627
# 77424    722
# 77425    715
# 77426    715
# 77427    721
# 77428    241
# 77429    719
# 77430    719
# 77431    786
# 77432    786
# 77433    790
# 77434    577
# 77435    577
# 77436    959
# 77437    719
# 77438    191
# 77439    151
# 77440    511
# 77441    V55
# 77442    V58
# 77443    V58
# Name: icd9, Length: 77444, dtype: object

# %%
'''
#Use groupby to match icd9 column with icd9_group column

umbrella_term = df['icd9'].groupby(df['icd9_group'])
list(df['icd9'].groupby(df['icd9_group'])) #Display the grouping
'''

# %%
#Function creates new column named icd9_group containing corresponding umbrella terms
terms = {}
def icd9_group(label, low, high):
    lst = np.arange(low, high+1, 1).astype(str).tolist()
    for i in lst:
        terms[i] = label
   
    return None

icd9_group('blood', 280, 289)
icd9_group('circulatory', 390, 459)
icd9_group('congenital', 740, 759)
icd9_group('digestive', 520, 579)
icd9_group('enmi', 240, 279)
icd9_group('genitourinary', 580, 629)
icd9_group('illdefined', 780, 799)
icd9_group('infectious', 0 , 139)
icd9_group('injury', 800, 999)
icd9_group('mental', 290, 319)
icd9_group('musculoskeletal', 710, 739)
icd9_group('neoplasms', 140, 239)
icd9_group('nervous', 320, 389)
icd9_group('obstetrics', 630, 679)
icd9_group('perinatal', 760, 779)
icd9_group('respiratory', 460, 519)
icd9_group('skin', 680, 709)
terms['blank'] = 'nan'
#icd9_group('supplemental', [^0-9])

# %%
df['icd9_group'] = [terms.get(i, 'supplemental') for i in df['icd9']]

# %%
df
# Out:
#                              Patient ID icd9       icd9_group
# 0      0000219e4b37d2504fb6b8c28e24a2d4  729  musculoskeletal
# 1      0000a7ddc7607d1d8ee5c47dd437034e  447      circulatory
# 2      0004fb840f61b62300e85fff9d5d5507  729  musculoskeletal
# 3      00069bac527f81cc1fd8f6a1d6ab8ec0  225        neoplasms
# 4      0006ff704be72d3514db32fcbbcb5885  351          nervous
# 5      00073f7be75bb844f0f713e98cc04197  V76     supplemental
# 6      0007c9e458254f57b98272fac909b8bb  626    genitourinary
# 7      0007c9e458254f57b98272fac909b8bb  V76     supplemental
# 8      0008252873a2b8ae0bb703f457fafa77  729  musculoskeletal
# 9      0008252873a2b8ae0bb703f457fafa77  729  musculoskeletal
# 10     000c15efbdf58caed528c09e597484ec  511      respiratory
# 11     00106b488de35153b7fce970acd03348  959           injury
# 12     00106b488de35153b7fce970acd03348  959           injury
# 13     00106b488de35153b7fce970acd03348  518      respiratory
# 14     00106b488de35153b7fce970acd03348  805           injury
# 15     00106b488de35153b7fce970acd03348  511      respiratory
# 16     00106b488de35153b7fce970acd03348  518      respiratory
# 17     00106b488de35153b7fce970acd03348  733  musculoskeletal
# 18     001267c30d69c8d2ad2f197e1673cfb6  714  musculoskeletal
# 19     0014e27ffc4cfa3c97aa42d20c3377e5  599    genitourinary
# 20     0014e27ffc4cfa3c97aa42d20c3377e5  625    genitourinary
# 21     00152e47bce6280dabc6c060328a797d  518      respiratory
# 22     00152e47bce6280dabc6c060328a797d  V45     supplemental
# 23     00152e47bce6280dabc6c060328a797d  414      circulatory
# 24     00152e47bce6280dabc6c060328a797d  511      respiratory
# 25     00155cfcd120e87cff07e823282114de  723  musculoskeletal
# 26     0015b408b2d74b2cef35cb24f9f58bcf  218        neoplasms
# 27     0015b408b2d74b2cef35cb24f9f58bcf  218        neoplasms
# 28     001641ede68b4af3eab24b76e46ec5eb  959           injury
# 29     001641ede68b4af3eab24b76e46ec5eb  959           injury
# ...                                 ...  ...              ...
# 77414  a18abe48de79fc3ca036093e31862929  786       illdefined
# 77415  a18c1e7398ae7196deb28af02960b534  733  musculoskeletal
# 77416  a18c1e7398ae7196deb28af02960b534  789       illdefined
# 77417  a18d418d2a25762a71bc62b436c843a1  V42     supplemental
# 77418  a18dc8a0cebf7cf24bf84381ab68f3de  786       illdefined
# 77419  a18e7237681e8f79ffc65d971144b573  780       illdefined
# 77420  a18e7237681e8f79ffc65d971144b573  722  musculoskeletal
# 77421  a18e7237681e8f79ffc65d971144b573  780       illdefined
# 77422  a18e7237681e8f79ffc65d971144b573  780       illdefined
# 77423  a18f6289b7f498df83d6bac1a09111b7  627    genitourinary
# 77424  a1933e04783e200cc90d4e60db514b42  722  musculoskeletal
# 77425  a193fc35fa09666dfea082a77351cd10  715  musculoskeletal
# 77426  a193fc35fa09666dfea082a77351cd10  715  musculoskeletal
# 77427  a193fc35fa09666dfea082a77351cd10  721  musculoskeletal
# 77428  a194822707d6cd46175c4019477d4af4  241             enmi
# 77429  a194a81f4bed9c03aff7fd012730f073  719  musculoskeletal
# 77430  a194a81f4bed9c03aff7fd012730f073  719  musculoskeletal
# 77431  a194a81f4bed9c03aff7fd012730f073  786       illdefined
# 77432  a1952b42280fc08cc60852b9f4e72726  786       illdefined
# 77433  a196ad8b7d9aee015fdf68a3570f77d3  790       illdefined
# 77434  a1987975765df46fa926f8285ba64b45  577        digestive
# 77435  a1987975765df46fa926f8285ba64b45  577        digestive
# 77436  a199167909d59805ee00593617083b62  959           injury
# 77437  a19a26a4d188ff00d18529d9df2f758f  719  musculoskeletal
# 77438  a19a7157660a79f6c444256ed3a8c67a  191        neoplasms
# 77439  a19ba0cb1324e165e07990b29567d3ce  151        neoplasms
# 77440  a19ba0cb1324e165e07990b29567d3ce  511      respiratory
# 77441  a19ba0cb1324e165e07990b29567d3ce  V55     supplemental
# 77442  a19ba0cb1324e165e07990b29567d3ce  V58     supplemental
# 77443  a19ba0cb1324e165e07990b29567d3ce  V58     supplemental
#
# [77444 rows x 3 columns]
